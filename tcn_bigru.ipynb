# %% [markdown]
# <a href="https://colab.research.google.com/github/ALPHA-CODE-HUB/Tcn-bigru-sequence-classifier/blob/main/tcn_bigru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-tcn
# Out:
# Requirement already satisfied: keras-tcn in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras-tcn) (1.26.4)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from keras-tcn) (2.18.0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.11/dist-packages (from keras-tcn) (0.23.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (0.37.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons->keras-tcn) (2.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->keras-tcn) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->keras-tcn) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->keras-tcn) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->keras-tcn) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->keras-tcn) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow->keras-tcn) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->keras-tcn) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->keras-tcn) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->keras-tcn) (0.1.2)

# %%
# !sed -i 's/self.build_output_shape.as_list()/list(self.build_output_shape)/g' /usr/local/lib/python3.11/dist-packages/tcn/tcn.py

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Bidirectional, GRU, BatchNormalization
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tcn import TCN
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.sequence import pad_sequences
data = pd.read_csv('/content/MalBehavD-V1-dataset.csv')
data = data.drop(columns=['sha256'])
y = data['labels']
api_calls = data.drop(columns=['labels']).fillna('')
api_calls = api_calls.apply(lambda x: ' '.join(x.dropna()), axis=1)

# %%
unique_calls = pd.Series(api_calls.str.split().sum()).unique()
label_encoder = LabelEncoder().fit(unique_calls)
api_calls_encoded = api_calls.apply(lambda x: label_encoder.transform(x.split()))

# %%
max_sequence_length = 150
X = pad_sequences(api_calls_encoded, maxlen=max_sequence_length, padding='post')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
unique_api_calls = len(label_encoder.classes_)
embedding_dim = 16

# %% [markdown]
# # **TCN-BIGRU**

# %%
model = Sequential(name="TCN-BiGRU_model")
model.add(Embedding(input_dim=unique_api_calls, output_dim=embedding_dim, input_length=max_sequence_length))
model.add(BatchNormalization())

# Use the original TCN layer after patching
model.add(TCN(nb_filters=64, kernel_size=9, dilations=[1, 2, 4, 8], activation='relu', return_sequences=True))

model.add(Bidirectional(GRU(units=256, return_sequences=False, dropout=0.3)))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)

history = model.fit(
    X_train, y_train,
    validation_split=0.3,
    epochs=80,
    batch_size=512,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 0.6333 - loss: 0.6566 - val_accuracy: 0.5302 - val_loss: 0.6924
# Epoch 2/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.6590 - loss: 0.6260 - val_accuracy: 0.5406 - val_loss: 0.6911
# Epoch 3/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - accuracy: 0.7090 - loss: 0.5955 - val_accuracy: 0.5941 - val_loss: 0.6882
# Epoch 4/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.7420 - loss: 0.5660 - val_accuracy: 0.5648 - val_loss: 0.6874
# Epoch 5/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 0.7730 - loss: 0.5365 - val_accuracy: 0.5941 - val_loss: 0.6854
# Epoch 6/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - accuracy: 0.7945 - loss: 0.5022 - val_accuracy: 0.6062 - val_loss: 0.6834
# Epoch 7/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 0.8033 - loss: 0.4751 - val_accuracy: 0.6269 - val_loss: 0.6811
# Epoch 8/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step - accuracy: 0.8183 - loss: 0.4451 - val_accuracy: 0.6028 - val_loss: 0.6786
# Epoch 9/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.8213 - loss: 0.4263 - val_accuracy: 0.6908 - val_loss: 0.6721
# Epoch 10/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.8288 - loss: 0.3954 - val_accuracy: 0.6494 - val_loss: 0.6694
# Epoch 11/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.8435 - loss: 0.3712 - val_accuracy: 0.7133 - val_loss: 0.6648
# Epoch 12/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.8468 - loss: 0.3504 - val_accuracy: 0.7409 - val_loss: 0.6601
# Epoch 13/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step - accuracy: 0.8773 - loss: 0.3261 - val_accuracy: 0.7340 - val_loss: 0.6554
# Epoch 14/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.8847 - loss: 0.2965 - val_accuracy: 0.7858 - val_loss: 0.6505
# Epoch 15/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.8996 - loss: 0.2865 - val_accuracy: 0.7703 - val_loss: 0.6481
# Epoch 16/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step - accuracy: 0.8941 - loss: 0.2754 - val_accuracy: 0.7807 - val_loss: 0.6421
# Epoch 17/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step - accuracy: 0.9088 - loss: 0.2572 - val_accuracy: 0.8411 - val_loss: 0.6349
# Epoch 18/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - accuracy: 0.9190 - loss: 0.2306 - val_accuracy: 0.7927 - val_loss: 0.6355
# Epoch 19/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.9227 - loss: 0.2235 - val_accuracy: 0.8411 - val_loss: 0.6281
# Epoch 20/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.9310 - loss: 0.2019 - val_accuracy: 0.8411 - val_loss: 0.6226
# Epoch 21/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.9397 - loss: 0.1884 - val_accuracy: 0.8584 - val_loss: 0.6125
# Epoch 22/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.9351 - loss: 0.1787 - val_accuracy: 0.8705 - val_loss: 0.6089
# Epoch 23/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.9274 - loss: 0.1830 - val_accuracy: 0.8670 - val_loss: 0.6025
# Epoch 24/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.9491 - loss: 0.1497 - val_accuracy: 0.8722 - val_loss: 0.5977
# Epoch 25/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.9534 - loss: 0.1394 - val_accuracy: 0.8722 - val_loss: 0.5896
# Epoch 26/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step - accuracy: 0.9595 - loss: 0.1354 - val_accuracy: 0.8895 - val_loss: 0.5797
# Epoch 27/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.9565 - loss: 0.1384 - val_accuracy: 0.8877 - val_loss: 0.5756
# Epoch 28/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.9617 - loss: 0.1264 - val_accuracy: 0.9171 - val_loss: 0.5675
# Epoch 29/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 0.9732 - loss: 0.1131 - val_accuracy: 0.9050 - val_loss: 0.5663
# Epoch 30/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - accuracy: 0.9690 - loss: 0.1049 - val_accuracy: 0.9102 - val_loss: 0.5597
# Epoch 31/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.9722 - loss: 0.0969 - val_accuracy: 0.9016 - val_loss: 0.5521
# Epoch 32/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - accuracy: 0.9797 - loss: 0.0912 - val_accuracy: 0.8826 - val_loss: 0.5499
# Epoch 33/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 0.9675 - loss: 0.0936 - val_accuracy: 0.9136 - val_loss: 0.5395
# Epoch 34/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 310ms/step - accuracy: 0.9803 - loss: 0.0779 - val_accuracy: 0.9171 - val_loss: 0.5302
# Epoch 35/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - accuracy: 0.9810 - loss: 0.0691 - val_accuracy: 0.9171 - val_loss: 0.5252
# Epoch 36/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 0.9812 - loss: 0.0666 - val_accuracy: 0.9223 - val_loss: 0.5196
# Epoch 37/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - accuracy: 0.9801 - loss: 0.0729 - val_accuracy: 0.9240 - val_loss: 0.5113
# Epoch 38/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step - accuracy: 0.9830 - loss: 0.0618 - val_accuracy: 0.9136 - val_loss: 0.5043
# Epoch 39/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 0.9881 - loss: 0.0597 - val_accuracy: 0.9085 - val_loss: 0.5050
# Epoch 40/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 0.9803 - loss: 0.0581 - val_accuracy: 0.9188 - val_loss: 0.4944
# Epoch 41/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 0.9873 - loss: 0.0528 - val_accuracy: 0.9171 - val_loss: 0.4879
# Epoch 42/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - accuracy: 0.9873 - loss: 0.0516 - val_accuracy: 0.9292 - val_loss: 0.4783
# Epoch 43/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 0.9931 - loss: 0.0438 - val_accuracy: 0.9206 - val_loss: 0.4711
# Epoch 44/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.9902 - loss: 0.0455 - val_accuracy: 0.9206 - val_loss: 0.4714
# Epoch 45/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.9873 - loss: 0.0450 - val_accuracy: 0.9171 - val_loss: 0.4635
# Epoch 46/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - accuracy: 0.9923 - loss: 0.0379 - val_accuracy: 0.9223 - val_loss: 0.4593
# Epoch 47/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.9948 - loss: 0.0319 - val_accuracy: 0.9206 - val_loss: 0.4506
# Epoch 48/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.9904 - loss: 0.0327 - val_accuracy: 0.9257 - val_loss: 0.4432
# Epoch 49/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - accuracy: 0.9909 - loss: 0.0340 - val_accuracy: 0.9257 - val_loss: 0.4335
# Epoch 50/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.9909 - loss: 0.0346 - val_accuracy: 0.9292 - val_loss: 0.4325
# Epoch 51/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.9943 - loss: 0.0291 - val_accuracy: 0.9275 - val_loss: 0.4232
# Epoch 52/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step - accuracy: 0.9899 - loss: 0.0321 - val_accuracy: 0.9136 - val_loss: 0.4204
# Epoch 53/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - accuracy: 0.9972 - loss: 0.0232 - val_accuracy: 0.9396 - val_loss: 0.4094
# Epoch 54/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.9964 - loss: 0.0228 - val_accuracy: 0.9344 - val_loss: 0.4016
# Epoch 55/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.9893 - loss: 0.0296 - val_accuracy: 0.9240 - val_loss: 0.3998
# Epoch 56/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - accuracy: 0.9937 - loss: 0.0209 - val_accuracy: 0.9206 - val_loss: 0.3958
# Epoch 57/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - accuracy: 0.9957 - loss: 0.0250 - val_accuracy: 0.9326 - val_loss: 0.3853
# Epoch 58/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.9890 - loss: 0.0260 - val_accuracy: 0.9240 - val_loss: 0.3877
# Epoch 59/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.9977 - loss: 0.0207 - val_accuracy: 0.9361 - val_loss: 0.3707
# Epoch 60/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.9934 - loss: 0.0208 - val_accuracy: 0.9361 - val_loss: 0.3734
# Epoch 61/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 0.9968 - loss: 0.0183 - val_accuracy: 0.9223 - val_loss: 0.3695
# Epoch 62/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 0.9979 - loss: 0.0190 - val_accuracy: 0.9257 - val_loss: 0.3587
# Epoch 63/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.9963 - loss: 0.0177 - val_accuracy: 0.9413 - val_loss: 0.3543
# Epoch 64/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 0.9971 - loss: 0.0169 - val_accuracy: 0.9223 - val_loss: 0.3504
# Epoch 65/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 0.9978 - loss: 0.0176 - val_accuracy: 0.9292 - val_loss: 0.3387
# Epoch 66/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 0.9935 - loss: 0.0178 - val_accuracy: 0.9344 - val_loss: 0.3375
# Epoch 67/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - accuracy: 0.9978 - loss: 0.0147 - val_accuracy: 0.9292 - val_loss: 0.3292
# Epoch 68/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.9973 - loss: 0.0180 - val_accuracy: 0.9361 - val_loss: 0.3241
# Epoch 69/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.9969 - loss: 0.0140 - val_accuracy: 0.9361 - val_loss: 0.3228
# Epoch 70/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 0.9946 - loss: 0.0159 - val_accuracy: 0.9275 - val_loss: 0.3178
# Epoch 71/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.9968 - loss: 0.0133 - val_accuracy: 0.9292 - val_loss: 0.3150
# Epoch 72/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 0.9961 - loss: 0.0137 - val_accuracy: 0.9447 - val_loss: 0.3056
# Epoch 73/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 0.9968 - loss: 0.0110 - val_accuracy: 0.9396 - val_loss: 0.2971
# Epoch 74/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.9968 - loss: 0.0138 - val_accuracy: 0.9344 - val_loss: 0.2937
# Epoch 75/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.9966 - loss: 0.0137 - val_accuracy: 0.9465 - val_loss: 0.2902
# Epoch 76/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step - accuracy: 0.9989 - loss: 0.0085 - val_accuracy: 0.9344 - val_loss: 0.3007
# Epoch 77/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 0.9959 - loss: 0.0128 - val_accuracy: 0.9396 - val_loss: 0.2826
# Epoch 78/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step - accuracy: 0.9973 - loss: 0.0127 - val_accuracy: 0.9344 - val_loss: 0.2748
# Epoch 79/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.9967 - loss: 0.0109 - val_accuracy: 0.9447 - val_loss: 0.2656
# Epoch 80/80
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.9994 - loss: 0.0076 - val_accuracy: 0.9275 - val_loss: 0.2675
# Restoring model weights from the end of the best epoch: 79.

# %% [markdown]
# # **RESULTS**

# %%
history_dict = history.history

best_train_accuracy = max(history_dict['accuracy'])
best_val_accuracy = max(history_dict['val_accuracy'])

best_train_loss = min(history_dict['loss'])
best_val_loss = min(history_dict['val_loss'])

best_train_accuracy_epoch = history_dict['accuracy'].index(best_train_accuracy) + 1
best_val_accuracy_epoch = history_dict['val_accuracy'].index(best_val_accuracy) + 1

best_train_loss_epoch = history_dict['loss'].index(best_train_loss) + 1
best_val_loss_epoch = history_dict['val_loss'].index(best_val_loss) + 1

print(f"Best Training Accuracy: {best_train_accuracy:.4f} (Epoch {best_train_accuracy_epoch})")
print(f"Best Validation Accuracy: {best_val_accuracy:.4f} (Epoch {best_val_accuracy_epoch})")

print(f"Best Training Loss: {best_train_loss:.4f} (Epoch {best_train_loss_epoch})")
print(f"Best Validation Loss: {best_val_loss:.4f} (Epoch {best_val_loss_epoch})")
# Out:
# Best Training Accuracy: 0.9993 (Epoch 76)
# Best Validation Accuracy: 0.9465 (Epoch 75)
# Best Training Loss: 0.0076 (Epoch 80)
# Best Validation Loss: 0.2656 (Epoch 79)

# %% [markdown]
# # **Training**

# %%
fig, ax = plt.subplots(1, 2, figsize=[12, 6])
ax[0].plot(history.history["loss"], label="Training Loss")
ax[0].plot(history.history["val_loss"], label="Validation Loss")
ax[0].set_title("Loss")
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(history.history["accuracy"], label="Training Accuracy")
ax[1].plot(history.history["val_accuracy"], label="Validation Accuracy")
ax[1].set_title("Accuracy")
ax[1].legend()
ax[1].set_xlabel("Epochs")

plt.show()

# %% [markdown]
# # **MODEL EVALUTION**

# %%
y_pred = model.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)

print("TCN-BiGRU model classification report: \n\n", classification_report(np.array(y_test), y_pred_binary.flatten()))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# TCN-BiGRU model classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       326
#            1       0.95      0.89      0.92       317
#
#     accuracy                           0.92       643
#    macro avg       0.92      0.92      0.92       643
# weighted avg       0.92      0.92      0.92       643

# %% [markdown]
# # **CONFUSION MATRIX**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_binary)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malware'], yticklabels=['Benign', 'Malware'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # **Receiver operating characteristic (ROC) curve**

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})", color="blue")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend()
plt.show()

# %% [markdown]
# # **Precision-Recall curve**

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, _ = precision_recall_curve(y_test, y_pred)


plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label="Precision-Recall Curve", color="blue")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()
